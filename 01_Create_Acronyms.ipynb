# %% [markdown]
# # Creating Acronyms Using Python #

# %%
user_input = input("Enter the string u want to convert into acronyms")
str = user_input.split()
# Out:
# Enter the string u want to convert into acronyms Memberof Legislature Assembly

# %%
ans=""
for i in str:
    ans+=i[0].upper()

# %%
ans
# Out:
# 'MLA'
